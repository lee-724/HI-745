# %%
# Getting Data from Github
# !wget -q https://raw.githubusercontent.com/Luo-Innovation-Lab/Big-Data/main/3-customer-orders.csv

# Verify the files are downloaded
# !ls -lh 3-customer-orders.csv
# Out:
# -rw-r--r-- 1 root root 144K Feb 16 20:48 3-customer-orders.csv

# %%
# Import the needed tools to configure and control the system from pyspark library
from pyspark import SparkConf, SparkContext

# Create a 'Configuration' object to define how the program should run
# .setMaster("local") is commanding the code to run on your own computer
# .setAppName("Adverse_Event") gives the specific task a name for the logs
conf = SparkConf().setMaster("local").setAppName("TotalSpending")

# Creating the 'Spark Context', which is an entry point for all Spark functions
# It takes the configuration, and starts the engine
sc = SparkContext(conf = conf)

# %%
def custID(line):
  fields = line.split(',')
  custID = int(fields[0])
  spending = float(fields[2])
  return (custID, spending)

# Load the CSV file as an RDD
input = sc.textFile("3-customer-orders.csv")

# mapping the key-value pairs
rdd = input.map(custID)

# Add up amount spent by customer ID
TotSpendCust = rdd.reduceByKey(lambda x, y: x+ y)

# sort by count and collect them from the RDD to the driver
# sortedResults = TotSpendCust.sortBy(lambda x: x[1], ascending = False)
sortedResults = TotSpendCust.sortBy(lambda x: x[0]).collect();

# Print the results
for result in sortedResults: # Iterate directly over the already collected sortedResults list
  print(result)

# Stop the SparkContext
sc.stop()
# Out:
# (0, 5524.949999999998)
# (1, 4958.600000000001)
# (2, 5994.59)
# (3, 4659.63)
# (4, 4815.050000000002)
# (5, 4561.069999999999)
# (6, 5397.879999999998)
# (7, 4755.070000000001)
# (8, 5517.240000000001)
# (9, 5322.649999999999)
# (10, 4819.700000000001)
# (11, 5152.290000000002)
# (12, 4664.589999999998)
# (13, 4367.62)
# (14, 4735.030000000001)
# (15, 5413.510000000001)
# (16, 4979.06)
# (17, 5032.679999999999)
# (18, 4921.27)
# (19, 5059.4299999999985)
# (20, 4836.859999999999)
# (21, 4707.41)
# (22, 5019.449999999999)
# (23, 4042.6499999999987)
# (24, 5259.920000000003)
# (25, 5057.610000000001)
# (26, 5250.4)
# (27, 4915.889999999999)
# (28, 5000.709999999998)
# (29, 5032.529999999999)
# (30, 4990.72)
# (31, 4765.05)
# (32, 5496.050000000004)
# (33, 5254.659999999998)
# (34, 5330.8)
# (35, 5155.419999999999)
# (36, 4278.049999999997)
# (37, 4735.200000000002)
# (38, 4898.460000000002)
# (39, 6193.109999999999)
# (40, 5186.429999999999)
# (41, 5637.62)
# (42, 5696.840000000003)
# ...
