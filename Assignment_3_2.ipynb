# %%
# Getting Data from Github
# !wget -q https://raw.githubusercontent.com/Luo-Innovation-Lab/Big-Data/main/3-customer-orders.csv

# Verify the files are downloaded
# !ls -lh 3-customer-orders.csv
# Out:
# -rw-r--r-- 1 root root 144K Feb 16 21:18 3-customer-orders.csv

# %%
# Import the needed tools to configure and control the system from pyspark library
from pyspark import SparkConf, SparkContext

# Create a 'Configuration' object to define how the program should run
# .setMaster("local") is commanding the code to run on your own computer
# .setAppName("Adverse_Event") gives the specific task a name for the logs
conf = SparkConf().setMaster("local").setAppName("TotalSpendingFlip")

# Creating the 'Spark Context', which is an entry point for all Spark functions
# It takes the configuration, and starts the engine
sc = SparkContext(conf = conf)

# %%
def custID(line):
  fields = line.split(',')
  custID = int(fields[0])
  spending = float(fields[2])
  return (custID, spending)

# Load the CSV file as an RDD
input = sc.textFile("3-customer-orders.csv")

# mapping the key-value pairs
rdd = input.map(custID)

# Add up amount spent by customer ID
TotSpendCust = rdd.reduceByKey(lambda x, y: x+ y)

# sort by count and collect them from the RDD to the driver
sortedResults = TotSpendCust.sortBy(lambda x: x[0])

# flip key and value
flipped = sortedResults.map(lambda x: (x[1], x[0]))

# sort by count and collect them from the RDD to the driver
# sortedResults = TotSpendCust.sortBy(lambda x: x[1], ascending = False)
results = flipped.sortByKey().collect();

# Print the results
for result in results: # Iterate directly over the already collected sortedResults list
  print(result)

# Stop the SparkContext
sc.stop()
# Out:
# (3309.38, 45)
# (3790.570000000001, 79)
# (3924.230000000001, 96)
# (4042.6499999999987, 23)
# (4172.289999999998, 99)
# (4178.500000000001, 75)
# (4278.049999999997, 36)
# (4297.260000000001, 98)
# (4316.299999999999, 47)
# (4327.729999999999, 77)
# (4367.62, 13)
# (4384.33, 48)
# (4394.599999999999, 49)
# (4475.569999999999, 94)
# (4505.79, 67)
# (4517.27, 50)
# (4524.509999999999, 78)
# (4561.069999999999, 5)
# (4628.4, 57)
# (4635.799999999997, 83)
# (4642.259999999999, 91)
# (4647.129999999999, 74)
# (4652.939999999999, 84)
# (4659.63, 3)
# (4664.589999999998, 12)
# (4681.919999999999, 66)
# (4701.019999999999, 56)
# (4707.41, 21)
# (4727.860000000001, 80)
# (4735.030000000001, 14)
# (4735.200000000002, 37)
# (4755.070000000001, 7)
# (4756.8899999999985, 44)
# (4765.05, 31)
# (4812.489999999998, 82)
# (4815.050000000002, 4)
# (4819.700000000001, 10)
# (4830.549999999999, 88)
# (4836.859999999999, 20)
# (4851.479999999999, 89)
# (4876.840000000002, 95)
# (4898.460000000002, 38)
# ...
